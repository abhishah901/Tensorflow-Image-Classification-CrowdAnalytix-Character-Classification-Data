# %%
import tensorflow as tf
import os
from PIL import *
import random

# %%
path = "D:\comp\CAX Charac\CAX_Characters_Train\CAX_Characters_Train"
hold_classes = os.listdir(path)
print(hold_classes)
# Out:
# ['angrybirds', 'Baloo', 'Bart simpson', 'ben', 'bulbasaur', 'charizard', 'Charlie brown', 'charmander', 'Chicken_little', 'Cinderella', 'darth_vader', 'disney_princes', 'donald_duck', 'Godzilla', 'Goku_1', 'goofy', 'han-solo', 'harry_potter', 'hellokitty', 'itachi', 'John Cena', 'jojosiwa', 'kakashi', 'marilyn_monroe', 'mickey_mouse', 'minions', 'naruto', 'pikachu', 'pokemon', 'popeye', 'power_rangers', 'R2-D2', 'Roman Reigns', 'Scoopy Doo', 'SpongeBob SquarePants', 'squirtle', 'teenage_mutant', 'Tom and Jerry', 'toy_story_characters', 'vampirina', 'vegeta', 'Winnie the poo']

# %%
filenames = []
labels = []

# %%
os.listdir(path+'\\ben')
# Out:
# ['Cax_train645.jpg',
#  'Cax_train646.jpg',
#  'Cax_train647.jpg',
#  'Cax_train648.jpg',
#  'Cax_train649.jpg',
#  'Cax_train650.jpg',
#  'Cax_train651.jpg',
#  'Cax_train652.jpg',
#  'Cax_train653.jpg',
#  'Cax_train654.jpg',
#  'Cax_train655.jpg',
#  'Cax_train656.jpg',
#  'Cax_train657.jpg',
#  'Cax_train658.jpg',
#  'Cax_train659.jpg',
#  'Cax_train660.jpg',
#  'Cax_train661.jpg',
#  'Cax_train662.jpg',
#  'Cax_train663.jpg',
#  'Cax_train664.jpg',
#  'Cax_train665.jpg',
#  'Cax_train666.jpg',
#  'Cax_train667.jpg',
#  'Cax_train668.jpg',
#  'Cax_train669.jpg',
#  'Cax_train670.jpg',
#  'Cax_train671.jpg',
#  'Cax_train672.jpg',
#  'Cax_train673.jpg',
#  'Cax_train674.jpg',
#  'Cax_train675.jpg',
#  'Cax_train676.jpg',
#  'Cax_train677.jpg',
#  'Cax_train678.jpg',
#  'Cax_train679.jpg',
#  'Cax_train680.jpg',
#  'Cax_train681.jpg',
#  'Cax_train682.jpg',
#  'Cax_train683.jpg',
#  'Cax_train684.jpg',
#  'Cax_train685.jpg',
#  'Cax_train686.jpg',
#  'Cax_train687.jpg',
# ...

# %%
for i in range(len(hold_classes)):
    holder = [path +'\\'+ hold_classes[i] +'\\' + fname for fname in os.listdir(path+'\\'+hold_classes[i])]
    filenames.append(holder)
    for j in range(len(holder)):
        labels.append(hold_classes[i])

# %%
labels[:5]
# Out:
# ['angrybirds', 'angrybirds', 'angrybirds', 'angrybirds', 'angrybirds']

# %%
filenames[:5]
# Out:
# [['D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_TrainangrybirdsCax_train1.jpg',
#   'D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_TrainangrybirdsCax_train10.jpg',
#   'D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_TrainangrybirdsCax_train100.jpg',
#   'D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_TrainangrybirdsCax_train101.jpg',
#   'D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_TrainangrybirdsCax_train102.jpg',
#   'D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_TrainangrybirdsCax_train103.jpg',
#   'D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_TrainangrybirdsCax_train104.jpg',
#   'D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_TrainangrybirdsCax_train105.jpg',
#   'D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_TrainangrybirdsCax_train106.jpg',
#   'D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_TrainangrybirdsCax_train107.jpg',
# ...

# %%
flat_list = [item for sublist in filenames for item in sublist]

# %%
flat_list[:5]
# Out:
# ['D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_Train\\angrybirds\\Cax_train1.jpg',
#  'D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_Train\\angrybirds\\Cax_train10.jpg',
#  'D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_Train\\angrybirds\\Cax_train100.jpg',
#  'D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_Train\\angrybirds\\Cax_train101.jpg',
#  'D:\\comp\\CAX Charac\\CAX_Characters_Train\\CAX_Characters_Train\\angrybirds\\Cax_train102.jpg']

# %%
from PIL import Image
im = Image.open(random.choice(flat_list))
im.show()

# %%
len(flat_list)
# Out:
# 6694

# %%
len(labels)
# Out:
# 6694
